# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Improting CSV file (dataset)

# %%
data=pd.read_csv("C:/Users/HP/OneDrive/Desktop/STUDIES/all_data_copy.csv")
data
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 373695   259353    AAA Batteries (4-pack)                3       2.99
# 373696   259354                    iPhone                1        700
# 373697   259355                    iPhone                1        700
# 373698   259356    34in Ultrawide Monitor                1     379.99
# 373699   259357      USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# #  summary of the loaded dataset

# %%
# Monthly Sales Analysis of different electronics are given in dataset

# %% [markdown]
# # Cleaning and moulding the given dataset

# %% [markdown]
# # 1.Finding NA values in dataset

# %%
data.isnull().sum()
# Out:
# Order ID            1090
# Product             1090
# Quantity Ordered    1090
# Price Each          1090
# Order Date          1090
# Purchase Address    1090
# dtype: int64

# %% [markdown]
# # 2.Deleting NA values in dataset

# %%
data=data.dropna()
data
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 373695   259353    AAA Batteries (4-pack)                3       2.99
# 373696   259354                    iPhone                1        700
# 373697   259355                    iPhone                1        700
# 373698   259356    34in Ultrawide Monitor                1     379.99
# 373699   259357      USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# # 3.Finding Duplicate values in dataset

# %%
data.duplicated(subset=None, keep='first')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 373695     True
# 373696     True
# 373697     True
# 373698     True
# 373699     True
# Length: 372610, dtype: bool

# %% [markdown]
# # 4.Removing duplicate values in dataset

# %%
data=data.drop_duplicates()
data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %% [markdown]
# # 5.Slicing the order date column values to Date and Month column

# %%
data['Date'] = data['Order Date'].str[:8]
data['Month'] = data['Order Date'].str[:2]
data.head()
# Out:
# <ipython-input-56-7436bd838158>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Date'] = data['Order Date'].str[:8]
# <ipython-input-56-7436bd838158>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Month'] = data['Order Date'].str[:2]
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# ...

# %% [markdown]
# #  6.checking the unique value counts in months

# %%
data.Month.value_counts()
# Out:
# 12    24944
# 10    20249
# 04    18257
# 11    17544
# 05    16552
# 03    15128
# 07    14275
# 06    13535
# 02    11957
# 08    11943
# 09    11603
# 01     9699
# Or        1
# Name: Month, dtype: int64

# %% [markdown]
# # 7.removing 'Or' values in Month Column

# %%
data = data[data['Order Date'].str[:2] != 'Or']
data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address      Date Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016  01/17/19    01
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  01/05/19    01
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301  01/25/19    01

# %% [markdown]
# # 8.Checking the months column

# %%
data.Month.value_counts()
# Out:
# 12    24944
# 10    20249
# 04    18257
# 11    17544
# 05    16552
# 03    15128
# 07    14275
# 06    13535
# 02    11957
# 08    11943
# 09    11603
# 01     9699
# Name: Month, dtype: int64

# %% [markdown]
# # 9.Identifying the length of a dataset

# %%
data.shape
# Out:
# (185686, 8)

# %% [markdown]
# # 10.Datatype of each column in dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  object
#  3   Price Each        185686 non-null  object
#  4   Order Date        185686 non-null  object
#  5   Purchase Address  185686 non-null  object
#  6   Date              185686 non-null  object
#  7   Month             185686 non-null  object
# dtypes: object(8)
# memory usage: 12.8+ MB

# %% [markdown]
# # 11.Converting datatype in dataset
# (Order Date and Date column into datetime data type)

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Date'] = pd.to_datetime(data['Date'])
data['Month'] = data['Month'].astype('int32')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  object
#  3   Price Each        185686 non-null  object
#  4   Order Date        185686 non-null  datetime64[ns]
#  5   Purchase Address  185686 non-null  object
#  6   Date              185686 non-null  datetime64[ns]
#  7   Month             185686 non-null  int32
# dtypes: datetime64[ns](2), int32(1), object(5)
# memory usage: 12.0+ MB
# <ipython-input-62-0cbebfe771da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # 11.checking the unique values in Dataset

# %%
data.nunique()
# Out:
# Order ID            178437
# Product                 19
# Quantity Ordered         9
# Price Each              23
# Order Date          142395
# Purchase Address    140787
# Date                   366
# Month                   12
# dtype: int64

# %% [markdown]
# #  12.Converting Quantity Ordered column to Integer and Price Column to float.

# %%
data['Quantity Ordered'] = data['Quantity Ordered'].astype('int32')
data['Price Each'] = data['Price Each'].astype('float64')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  int32
#  3   Price Each        185686 non-null  float64
#  4   Order Date        185686 non-null  datetime64[ns]
#  5   Purchase Address  185686 non-null  object
#  6   Date              185686 non-null  datetime64[ns]
#  7   Month             185686 non-null  int32
# dtypes: datetime64[ns](2), float64(1), int32(2), object(3)
# memory usage: 11.3+ MB
# <ipython-input-64-fe43f78c38b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# we have 2 Integer Columns and 1 Float Column so now we can use describe method on our dataset

# %% [markdown]
# #  13.basic statistical details

# %%
data.describe()
# Out:
#        Quantity Ordered     Price Each          Month
# count     185686.000000  185686.000000  185686.000000
# mean           1.124544     184.519255       7.058653
# std            0.443069     332.843838       3.502932
# min            1.000000       2.990000       1.000000
# 25%            1.000000      11.950000       4.000000
# 50%            1.000000      14.950000       7.000000
# 75%            1.000000     150.000000      10.000000
# max            9.000000    1700.000000      12.000000

# %%
# Maximum Quantity Ordered is 9

# %% [markdown]
# # 14.Making sales column for further analysis

# %%
data['Sales'] = data['Quantity Ordered'] * data['Price Each']
data.head()
# Out:
# <ipython-input-68-ca7614748e09>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sales'] = data['Quantity Ordered'] * data['Price Each']
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address       Date  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215 2019-01-22
# ...

# %% [markdown]
# # 15.Adding city column in dataset

# %%
data['City'] = data['Purchase Address'].apply(lambda x: x.split(',')[1])
data.head()
# Out:
# <ipython-input-69-bc20db48a3ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['City'] = data['Purchase Address'].apply(lambda x: x.split(',')[1])
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address       Date  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215 2019-01-22
# ...

# %% [markdown]
# # summary of the cleaned dataset

# %%
# Given dataset has Null values, Duplicate values and Sales, Date,Time column was not given
# Cleaned dataset has removed all Null ,Duplicate values and by slicing "order date" column to Date ,Month were created
# New columns were created like Sales,City,State ,Address
# Given dataset contains six columns but cleaned and moulded data contains 13 columns.
# So cleaned data will be easier for further analysis

# %% [markdown]
# #  Identifying the month which had more sales

# %%
sales = data.groupby('Month')[['Quantity Ordered','Price Each','Sales']].sum()
months = range(1, 13)
plt.bar(months, sales['Sales'])
plt.title('Sales per Month')
plt.xticks(months)
plt.xlabel('Months')
plt.ylabel('Sales')
plt.show()
sales
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10893  1.810925e+06  1.821413e+06
# 2                 13431  2.186940e+06  2.200078e+06
# 3                 16979  2.789085e+06  2.804973e+06
# 4                 20536  3.366219e+06  3.389218e+06
# 5                 18653  3.133135e+06  3.150616e+06
# 6                 15234  2.560504e+06  2.576280e+06
# 7                 16054  2.631225e+06  2.646461e+06
# 8                 13429  2.226964e+06  2.241083e+06
# 9                 13091  2.081898e+06  2.094466e+06
# 10                22669  3.713609e+06  3.734778e+06
# 11                19769  3.178873e+06  3.197875e+06
# 12                28074  4.583268e+06  4.608296e+06

# %%
#Sales are High during December because of Various Reason.

#Most People Wait for Offers to Buy at Low Prices during Clearance Sales.
#Ex: New Year Sale | Offers.
#Ex: Christmas Sale | Offers.

# %% [markdown]
# # Identifying most bought products per city

# %%
x=data.City.value_counts()
sns.countplot(y ='City', data = data) 
plt.xlabel('Total number of Products')
plt.show()
x
# Out:
#  San Francisco    44662
#  Los Angeles      29564
#  New York City    24847
#  Boston           19901
#  Atlanta          14863
#  Dallas           14797
#  Seattle          14713
#  Portland         12449
#  Austin            9890
# Name: City, dtype: int64

# %%
# People in city called San Francisco buy more number of products whereas People from Austin buy less number of products

# %% [markdown]
# #  Slicing city and state from Purchase address in dataset

# %%
state = data['Purchase Address'].apply(lambda x: x.split(', ')[2])
state = state.str[:2]
data['State'] = state
data['Address'] = data['City'] + " " + data['State']
data.head()
# Out:
# <ipython-input-75-2f4ba5bd001c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['State'] = state
# <ipython-input-75-2f4ba5bd001c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Address'] = data['City'] + " " + data['State']
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# ...

# %% [markdown]
# #  Identifying the city which had the highest sales overall

# %%
result_address = data.groupby(['Address']).sum()
city = [c for c, df in data.groupby('Address')]
plt.bar(city, result_address['Sales'])
plt.title('Sales per City')
plt.xticks(result_address.index, rotation='vertical')
plt.xlabel('Cities')
plt.ylabel('Sales')
plt.show()
result_address
# Out:
#                    Quantity Ordered    Price Each   Month         Sales
# Address
#  Atlanta GA                   16584  2.778609e+06  104649  2.794199e+06
#  Austin TX                    11137  1.808340e+06   69720  1.818044e+06
#  Boston MA                    22494  3.634398e+06  140898  3.658628e+06
#  Dallas TX                    16707  2.750026e+06  104447  2.765374e+06
#  Los Angeles CA               33247  5.417172e+06  208020  5.448304e+06
#  New York City NY             27903  4.632921e+06  175557  4.661867e+06
#  Portland ME                   2746  4.467524e+05   17119  4.493214e+05
#  Portland OR                  11291  1.859836e+06   70517  1.870011e+06
#  San Francisco CA             50169  8.204001e+06  314949  8.254744e+06
#  Seattle WA                   16534  2.730587e+06  104817  2.745046e+06

# %%
# We know that sales are directly propotional to number of products bought.
# Since more number of products bought from San Francisco, Sales will be higher
# Less number of products bought in Austin. So sales are lower

# %% [markdown]
#  Best city for new branch is San Francisco
# because sales and products that were bought from this city is very higher

# %% [markdown]
# # Adding hour column in dataset

# %%
data['Hour'] = data['Order Date'].dt.hour
data.head()
# Out:
# <ipython-input-78-38aa4d65e742>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Hour'] = data['Order Date'].dt.hour
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address       Date  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215 2019-01-22
# ...

# %% [markdown]
# # Function for Part_Of_Day

# %%
def get_part_of_day(h):
    return (
        "morning"
        if 5 <= h <= 11
        else "afternoon"
        if 12 <= h <= 17
        else "evening"
        if 18 <= h <= 22
        else "night"
    )

# %% [markdown]
# # Creating Part_Of_Day Column

# %%
data['Part_Of_Day'] = data['Hour'].apply(get_part_of_day)
data
# Out:
# <ipython-input-80-518618b40c6c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Part_Of_Day'] = data['Hour'].apply(get_part_of_day)
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# ...

# %% [markdown]
# # Identifying which Product was Sold Most Frequenctly

# %%
product_group = data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']
products = [product for product, detail in product_group]

plt.figure(figsize = (20,5))
plt.bar(products, quantity_ordered)
plt.xticks(products, rotation = 'vertical')
plt.title('Most Sold Products')
plt.xlabel('Products')
plt.ylabel('Quantity of Products');

# %%
# AA and AAA Batteries are Sold most because they are used vey Commonly in Remote, Clock, Toys etc.
# Charging Cables and Headphones are also Important Products for Daily Usage Purpose.
#Price also Matters, Product which are of High Price are not Purchased Regulary.

# %%
prices = data.groupby('Product').mean()['Price Each']
fig, ax1 = plt.subplots(figsize = (20,5))
ax2 = ax1.twinx() # Common X Axis
ax1.bar(products, quantity_ordered, color = 'blue')
ax2.plot(products, prices, color = 'red')
ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color = 'blue')
ax2.set_ylabel('Price in USD', color = 'red')
ax1.set_xticklabels(products, rotation = 'vertical');
# Out:
# <ipython-input-83-4ac65913a1fc>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products, rotation = 'vertical');

# %%
#Costly Products have Low Sale, because People dont Buy them Regularly.
#People Mostly Buy Costly Products during Festival Sales.

# %% [markdown]
# #  Products sold at different times of the day

# %%
x=data.groupby('Part_Of_Day')['Product'].count()
sns.countplot(x ='Part_Of_Day', data = data) 
plt.ylabel('Total number of Products')
plt.show()
x
# Out:
# Part_Of_Day
# afternoon    67055
# evening      57080
# morning      46116
# night        15435
# Name: Product, dtype: int64

# %%
# During afternoon more products are bought by people but during night less products are sold

# %% [markdown]
# # Identifying which time of day has the most sales

# %%
hours = [hour for hour, df in data.groupby('Hour')]
plt.figure(figsize = (20,5))
plt.plot(hours, data.groupby('Hour').count())
plt.grid(True)
plt.xticks(hours)
plt.xlabel('Hours in 24 Hr Format')
plt.ylabel('Orders')
plt.show()

# %%
# Customer Visits Store or Order more between 11a.m. to 1p.m. and 6p.m. to 8.00p.m

# %%
#During afternoon at 11:00 AM to 1:00 PM customers like to buy more products AA and AAA Batteries are Sold most

# %% [markdown]
# # Checking Order Id's which are repeating

# %%
order = data[data['Order ID'].duplicated(keep = False)] 
order.head(10)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 41    141275        USB-C Charging Cable                 1       11.95
# 42    141275            Wired Headphones                 1       11.99
# 57    141290    Apple Airpods Headphones                 1      150.00
# 58    141290       AA Batteries (4-pack)                 3        3.84
# 133   141365             Vareebadd Phone                 1      400.00
# 134   141365            Wired Headphones                 1       11.99
# 153   141384                Google Phone                 1      600.00
# 154   141384        USB-C Charging Cable                 1       11.95
# 220   141450                Google Phone                 1      600.00
# 221   141450  Bose SoundSport Headphones                 1       99.99
#
#              Order Date                        Purchase Address       Date  \
# 41  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301 2019-01-07
# ...

# %% [markdown]
# # Creating Group of Products Ordered together

# %%
order['Ordered Together'] = order.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
order = order[['Order ID','Ordered Together']].drop_duplicates()
order.head(10)
# Out:
# <ipython-input-91-68beef9dcce9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['Ordered Together'] = order.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
#     Order ID                                  Ordered Together
# 41    141275             USB-C Charging Cable,Wired Headphones
# 57    141290    Apple Airpods Headphones,AA Batteries (4-pack)
# 133   141365                  Vareebadd Phone,Wired Headphones
# 153   141384                 Google Phone,USB-C Charging Cable
# 220   141450           Google Phone,Bose SoundSport Headphones
# 228   141457                   iPhone,Apple Airpods Headphones
# 250   141478             Google Phone,Apple Airpods Headphones
# ...

# %% [markdown]
# # Products bought together

# %%
from itertools import combinations
from collections import Counter 

count = Counter()

for row in order['Ordered Together']:
    items = row.split(',')
    count.update(Counter(combinations(items,2))) # Most Common Pair of Products Bought Together.

for key, value in count.most_common(10): # Top 10 Products Pair Bought Together.
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1002
# ('Google Phone', 'USB-C Charging Cable') 985
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 413
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 159
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %%
#Based on the Group of Items Bought Together, Offers can be Provided to Attract more Customers.
#e.g. If a Person Buy Iphone, Discount Offers on Lightning Charging Cable.
#Sorting Frequently Bought Products helps to make Better Business Decisions.
